# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime
import gspread

# %%
SPOTIPY_CLIENT_ID='08c54b4fe8824e5693b53ee906156053'
SPOTIPY_CLIENT_SECRET='d776d34c991142378bca2f9812395a66'
SPOTIPY_REDIRECT_URI='http://127.0.0.1:9090'
SCOPE = "user-top-read"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID, 
                                               client_secret=SPOTIPY_CLIENT_SECRET, 
                                               redirect_uri=SPOTIPY_REDIRECT_URI, 
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20, offset=0, time_range="short_term")

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NbgKDsEHiPzZBZkqZGkXm'},
#       'href': 'https://api.spotify.com/v1/artists/0NbgKDsEHiPzZBZkqZGkXm',
#       'id': '0NbgKDsEHiPzZBZkqZGkXm',
#       'name': 'Mismatched - Cast',
#       'type': 'artist',
#       'uri': 'spotify:artist:0NbgKDsEHiPzZBZkqZGkXm'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0bPV8j4jfsKeoW5P3YQInX'},
#     'href': 'https://api.spotify.com/v1/albums/0bPV8j4jfsKeoW5P3YQInX',
#     'id': '0bPV8j4jfsKeoW5P3YQInX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27390853ed444266d1d2bb55c28',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0290853ed444266d1d2bb55c28',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485190853ed444266d1d2bb55c28',
#       'width': 64}],
#     'name': 'Mismatched: Season 2 (Soundtrack from the Netflix Series)',
#     'release_date': '2022-09-30',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:0bPV8j4jfsKeoW5P3YQInX'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4a5cFa2gISG9QtjELLgYcZ'},
#      'href': 'https://api.spotify.com/v1/artists/4a5cFa2gISG9QtjELLgYcZ',
#      'id': '4a5cFa2gISG9QtjELLgYcZ',
#      'name': 'Sickflip',
#      'type': 'artist',
#      'uri': 'spotify:artist:4a5cFa2gISG9QtjELLgYcZ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0NbgKDsEHiPzZBZkqZGkXm'},
#      'href': 'https://api.spotify.com/v1/artists/0NbgKDsEHiPzZBZkqZGkXm',
#      'id': '0NbgKDsEHiPzZBZkqZGkXm',
#      'name': 'Mismatched - Cast',
#      'type': 'artist',
#      'uri': 'spotify:artist:0NbgKDsEHiPzZBZkqZGkXm'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/03CXCirzmzFLNwU4frezp7'},
#      'href': 'https://api.spotify.com/v1/artists/03CXCirzmzFLNwU4frezp7',
#      'id': '03CXCirzmzFLNwU4frezp7',
#      'name': 'Raitila Rajasthan',
#      'type': 'artist',
#      'uri': 'spotify:artist:03CXCirzmzFLNwU4frezp7'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 170400,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ8BZ2201994'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3s5Rz3KFms39ZrFDw2jt4r'},
#    'href': 'https://api.spotify.com/v1/tracks/3s5Rz3KFms39ZrFDw2jt4r',
#    'id': '3s5Rz3KFms39ZrFDw2jt4r',
#    'is_local': False,
#    'name': 'Mehmaan',
#    'popularity': 44,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cdc3fb9dd8fa491ac6fd9635568e649c41611de7?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3s5Rz3KFms39ZrFDw2jt4r'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2VtuL4CYch8Vv8vzujEO8R'},
#       'href': 'https://api.spotify.com/v1/artists/2VtuL4CYch8Vv8vzujEO8R',
#       'id': '2VtuL4CYch8Vv8vzujEO8R',
#       'name': 'Yongjin Jeong',
#       'type': 'artist',
#       'uri': 'spotify:artist:2VtuL4CYch8Vv8vzujEO8R'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'MK',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4bURGIfK0r60qH6uv3qetk'},
#     'href': 'https://api.spotify.com/v1/albums/4bURGIfK0r60qH6uv3qetk',
#     'id': '4bURGIfK0r60qH6uv3qetk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27378129bba6aa1ae5f6f1c399b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0278129bba6aa1ae5f6f1c399b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485178129bba6aa1ae5f6f1c399b',
#       'width': 64}],
#     'name': 'Tale Of Cinema',
#     'release_date': '2001-11-06',
#     'release_date_precision': 'day',
#     'total_tracks': 41,
#     'type': 'album',
#     'uri': 'spotify:album:4bURGIfK0r60qH6uv3qetk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2VtuL4CYch8Vv8vzujEO8R'},
#      'href': 'https://api.spotify.com/v1/artists/2VtuL4CYch8Vv8vzujEO8R',
#      'id': '2VtuL4CYch8Vv8vzujEO8R',
#      'name': 'Yongjin Jeong',
#      'type': 'artist',
#      'uri': 'spotify:artist:2VtuL4CYch8Vv8vzujEO8R'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'MK',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET'],
#    'disc_number': 1,
#    'duration_ms': 195573,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR13V0500109'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7oZkLL5Xct7ygMlCKArnCC'},
#    'href': 'https://api.spotify.com/v1/tracks/7oZkLL5Xct7ygMlCKArnCC',
#    'id': '7oZkLL5Xct7ygMlCKArnCC',
#    'is_local': False,
#    'name': 'Main Title',
#    'popularity': 3,
#    'preview_url': 'https://p.scdn.co/mp3-preview/291f0aa2cb9eba990dfa31c725f2cd5b959ba9f7?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7oZkLL5Xct7ygMlCKArnCC'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6i50rQJbETLRREwFn3plcw'},
#       'href': 'https://api.spotify.com/v1/artists/6i50rQJbETLRREwFn3plcw',
#       'id': '6i50rQJbETLRREwFn3plcw',
#       'name': 'Lifafa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6i50rQJbETLRREwFn3plcw'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0iH6pbUrb45P62B82PHDLb'},
#     'href': 'https://api.spotify.com/v1/albums/0iH6pbUrb45P62B82PHDLb',
#     'id': '0iH6pbUrb45P62B82PHDLb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ccb8f637c8dd7422f4266bfa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ccb8f637c8dd7422f4266bfa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ccb8f637c8dd7422f4266bfa',
#       'width': 64}],
#     'name': 'Jaago',
#     'release_date': '2019-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:0iH6pbUrb45P62B82PHDLb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6i50rQJbETLRREwFn3plcw'},
#      'href': 'https://api.spotify.com/v1/artists/6i50rQJbETLRREwFn3plcw',
#      'id': '6i50rQJbETLRREwFn3plcw',
#      'name': 'Lifafa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6i50rQJbETLRREwFn3plcw'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tKsgOYV3Cwl7Fyzr2S6Ud'},
#      'href': 'https://api.spotify.com/v1/artists/3tKsgOYV3Cwl7Fyzr2S6Ud',
#      'id': '3tKsgOYV3Cwl7Fyzr2S6Ud',
#      'name': 'Hashback Hashish',
#      'type': 'artist',
#      'uri': 'spotify:artist:3tKsgOYV3Cwl7Fyzr2S6Ud'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 234856,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBLLT1900060'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3eNVm12Ns8BOk4NqgWcGI4'},
#    'href': 'https://api.spotify.com/v1/tracks/3eNVm12Ns8BOk4NqgWcGI4',
#    'id': '3eNVm12Ns8BOk4NqgWcGI4',
#    'is_local': False,
#    'name': 'Candy',
#    'popularity': 26,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a7c7993ddadad3f44b65eb65302c0d0d0d9b39b7?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:3eNVm12Ns8BOk4NqgWcGI4'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7Y2CNmpI13IevU3PuzCa'},
#       'href': 'https://api.spotify.com/v1/artists/3Y7Y2CNmpI13IevU3PuzCa',
#       'id': '3Y7Y2CNmpI13IevU3PuzCa',
#       'name': 'Esbe',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y7Y2CNmpI13IevU3PuzCa'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ceQKxT0GhryrHU5di7tmz'},
#     'href': 'https://api.spotify.com/v1/albums/2ceQKxT0GhryrHU5di7tmz',
#     'id': '2ceQKxT0GhryrHU5di7tmz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c828c300386f6c77b7419119',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c828c300386f6c77b7419119',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c828c300386f6c77b7419119',
#       'width': 64}],
#     'name': 'Bloomsday',
#     'release_date': '2015-12-11',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:2ceQKxT0GhryrHU5di7tmz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7Y2CNmpI13IevU3PuzCa'},
#      'href': 'https://api.spotify.com/v1/artists/3Y7Y2CNmpI13IevU3PuzCa',
#      'id': '3Y7Y2CNmpI13IevU3PuzCa',
#      'name': 'Esbe',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Y7Y2CNmpI13IevU3PuzCa'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 189090,
#    'explicit': False,
#    'external_ids': {'isrc': 'USEAX1502761'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ncNLU982iaD9WFb2gTwKd'},
#    'href': 'https://api.spotify.com/v1/tracks/6ncNLU982iaD9WFb2gTwKd',
#    'id': '6ncNLU982iaD9WFb2gTwKd',
#    'is_local': False,
#    'name': 'Darling',
#    'popularity': 65,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4091808d6e2f7c12773c1ebd1740450df46d5f01?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:6ncNLU982iaD9WFb2gTwKd'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2dk5Zz8Lcf4ym4UYt6ijQZ'},
#       'href': 'https://api.spotify.com/v1/artists/2dk5Zz8Lcf4ym4UYt6ijQZ',
#       'id': '2dk5Zz8Lcf4ym4UYt6ijQZ',
#       'name': 'Laurent Levesque',
#       'type': 'artist',
#       'uri': 'spotify:artist:2dk5Zz8Lcf4ym4UYt6ijQZ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3hojuUUd3QJL2XGwlnGZe0'},
#     'href': 'https://api.spotify.com/v1/albums/3hojuUUd3QJL2XGwlnGZe0',
#     'id': '3hojuUUd3QJL2XGwlnGZe0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eb7886044bb004d4b79d1442',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eb7886044bb004d4b79d1442',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eb7886044bb004d4b79d1442',
#       'width': 64}],
#     'name': 'Funeral',
#     'release_date': '2018-04-19',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:3hojuUUd3QJL2XGwlnGZe0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2dk5Zz8Lcf4ym4UYt6ijQZ'},
#      'href': 'https://api.spotify.com/v1/artists/2dk5Zz8Lcf4ym4UYt6ijQZ',
#      'id': '2dk5Zz8Lcf4ym4UYt6ijQZ',
#      'name': 'Laurent Levesque',
#      'type': 'artist',
#      'uri': 'spotify:artist:2dk5Zz8Lcf4ym4UYt6ijQZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 92440,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR26F1800741'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2wbirG6r5fn6UCzmKA8bpX'},
#    'href': 'https://api.spotify.com/v1/tracks/2wbirG6r5fn6UCzmKA8bpX',
#    'id': '2wbirG6r5fn6UCzmKA8bpX',
#    'is_local': False,
#    'name': 'Requiem Mass',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8852f16fa7da2b16da71dc8bc8343fb6d3b9bbe8?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2wbirG6r5fn6UCzmKA8bpX'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0d0Mx82DMxnPjVq3MtG4o5'},
#       'href': 'https://api.spotify.com/v1/artists/0d0Mx82DMxnPjVq3MtG4o5',
#       'id': '0d0Mx82DMxnPjVq3MtG4o5',
#       'name': 'Jesse Gallagher',
#       'type': 'artist',
#       'uri': 'spotify:artist:0d0Mx82DMxnPjVq3MtG4o5'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4agHu4lDYADAD7twQb2Qsf'},
#     'href': 'https://api.spotify.com/v1/albums/4agHu4lDYADAD7twQb2Qsf',
#     'id': '4agHu4lDYADAD7twQb2Qsf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730a4e6ad2800c26b04c8472ef',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020a4e6ad2800c26b04c8472ef',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510a4e6ad2800c26b04c8472ef',
#       'width': 64}],
#     'name': 'Sound to See ~ Visual Music, Vol. 2',
#     'release_date': '2019-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4agHu4lDYADAD7twQb2Qsf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0d0Mx82DMxnPjVq3MtG4o5'},
#      'href': 'https://api.spotify.com/v1/artists/0d0Mx82DMxnPjVq3MtG4o5',
#      'id': '0d0Mx82DMxnPjVq3MtG4o5',
#      'name': 'Jesse Gallagher',
#      'type': 'artist',
#      'uri': 'spotify:artist:0d0Mx82DMxnPjVq3MtG4o5'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 175360,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZES82079605'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/72l7APwXnXpffgZBCewEqX'},
#    'href': 'https://api.spotify.com/v1/tracks/72l7APwXnXpffgZBCewEqX',
#    'id': '72l7APwXnXpffgZBCewEqX',
#    'is_local': False,
#    'name': 'Obelisks',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0c2ba083a138eeddcafecdee780b94404daa4577?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:72l7APwXnXpffgZBCewEqX'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mVVjNmdjXZZDvhgQWiakk'},
#       'href': 'https://api.spotify.com/v1/artists/2mVVjNmdjXZZDvhgQWiakk',
#       'id': '2mVVjNmdjXZZDvhgQWiakk',
#       'name': 'Khruangbin',
#       'type': 'artist',
#       'uri': 'spotify:artist:2mVVjNmdjXZZDvhgQWiakk'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2IzUZlhtBvPQYs74KeG6fb'},
#     'href': 'https://api.spotify.com/v1/albums/2IzUZlhtBvPQYs74KeG6fb',
#     'id': '2IzUZlhtBvPQYs74KeG6fb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d0eca87ea7f362cf1b8fa19a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d0eca87ea7f362cf1b8fa19a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d0eca87ea7f362cf1b8fa19a',
#       'width': 64}],
#     'name': 'Mordechai',
#     'release_date': '2020-06-26',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2IzUZlhtBvPQYs74KeG6fb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2mVVjNmdjXZZDvhgQWiakk'},
#      'href': 'https://api.spotify.com/v1/artists/2mVVjNmdjXZZDvhgQWiakk',
#      'id': '2mVVjNmdjXZZDvhgQWiakk',
#      'name': 'Khruangbin',
#      'type': 'artist',
#      'uri': 'spotify:artist:2mVVjNmdjXZZDvhgQWiakk'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 260732,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ5G2019303'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0ibpvxLcFccvQJd0SjdUvW'},
#    'href': 'https://api.spotify.com/v1/tracks/0ibpvxLcFccvQJd0SjdUvW',
#    'id': '0ibpvxLcFccvQJd0SjdUvW',
#    'is_local': False,
#    'name': 'Connaissais de Face',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/51e3b004856bcecaf22518044d8c560a3f67a6ec?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0ibpvxLcFccvQJd0SjdUvW'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NZTfIao2GyoAiR3NhbrdL'},
#       'href': 'https://api.spotify.com/v1/artists/3NZTfIao2GyoAiR3NhbrdL',
#       'id': '3NZTfIao2GyoAiR3NhbrdL',
#       'name': 'Haythem Mahbouli',
#       'type': 'artist',
#       'uri': 'spotify:artist:3NZTfIao2GyoAiR3NhbrdL'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4e141trp3rhFB8Vtsz8C5S'},
#     'href': 'https://api.spotify.com/v1/albums/4e141trp3rhFB8Vtsz8C5S',
#     'id': '4e141trp3rhFB8Vtsz8C5S',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ce5c651f3f05a4a3d1e3f49e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ce5c651f3f05a4a3d1e3f49e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ce5c651f3f05a4a3d1e3f49e',
#       'width': 64}],
#     'name': 'Catching Moments in Time',
#     'release_date': '2019-04-26',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:4e141trp3rhFB8Vtsz8C5S'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NZTfIao2GyoAiR3NhbrdL'},
#      'href': 'https://api.spotify.com/v1/artists/3NZTfIao2GyoAiR3NhbrdL',
#      'id': '3NZTfIao2GyoAiR3NhbrdL',
#      'name': 'Haythem Mahbouli',
#      'type': 'artist',
#      'uri': 'spotify:artist:3NZTfIao2GyoAiR3NhbrdL'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 322144,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCJPI1986787'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1g7cixLX5jYl0uaTvYLM9V'},
#    'href': 'https://api.spotify.com/v1/tracks/1g7cixLX5jYl0uaTvYLM9V',
#    'id': '1g7cixLX5jYl0uaTvYLM9V',
#    'is_local': False,
#    'name': 'Catching the first moment',
#    'popularity': 4,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2f506b8b81adf7d8bc8b0e60701415c711a58598?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1g7cixLX5jYl0uaTvYLM9V'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zb7wVUx1vTXLB6HX26EnX'},
#       'href': 'https://api.spotify.com/v1/artists/5zb7wVUx1vTXLB6HX26EnX',
#       'id': '5zb7wVUx1vTXLB6HX26EnX',
#       'name': 'Oberhofer',
#       'type': 'artist',
#       'uri': 'spotify:artist:5zb7wVUx1vTXLB6HX26EnX'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4TAmYdA51CgKukT5moHIMh'},
#     'href': 'https://api.spotify.com/v1/albums/4TAmYdA51CgKukT5moHIMh',
#     'id': '4TAmYdA51CgKukT5moHIMh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c59a1af68ee4a33396660fbe',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c59a1af68ee4a33396660fbe',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c59a1af68ee4a33396660fbe',
#       'width': 64}],
# ...
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518c00742a7071524def6fbf65',
#       'width': 64}],
#     'name': 'Home',
#     'release_date': '2017-02-09',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:1HyHDKbhGqbKCAambfFW3p'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1FY8kqUQKHwjibwLbp5cey'},
#      'href': 'https://api.spotify.com/v1/artists/1FY8kqUQKHwjibwLbp5cey',
#      'id': '1FY8kqUQKHwjibwLbp5cey',
#      'name': 'Eelke Kleijn',
#      'type': 'artist',
#      'uri': 'spotify:artist:1FY8kqUQKHwjibwLbp5cey'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 562202,
#    'explicit': False,
#    'external_ids': {'isrc': 'NLF711700301'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/270jwLvqL7UJOdeUyxwafh'},
#    'href': 'https://api.spotify.com/v1/tracks/270jwLvqL7UJOdeUyxwafh',
#    'id': '270jwLvqL7UJOdeUyxwafh',
#    'is_local': False,
#    'name': 'Home - Extended Mix',
#    'popularity': 14,
#    'preview_url': 'https://p.scdn.co/mp3-preview/de4dd095522a8ff56abd5b86bd4df78e5745e721?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:270jwLvqL7UJOdeUyxwafh'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bs7HoMkSyQwcobCpE9KpN'},
#       'href': 'https://api.spotify.com/v1/artists/1bs7HoMkSyQwcobCpE9KpN',
#       'id': '1bs7HoMkSyQwcobCpE9KpN',
#       'name': 'The Mamas & The Papas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1bs7HoMkSyQwcobCpE9KpN'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0zR6CIh3f8DFFzIee5AWwp'},
#     'href': 'https://api.spotify.com/v1/albums/0zR6CIh3f8DFFzIee5AWwp',
#     'id': '0zR6CIh3f8DFFzIee5AWwp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27391d092488eaff72ece2451dd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0291d092488eaff72ece2451dd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485191d092488eaff72ece2451dd',
#       'width': 64}],
#     'name': 'Deliver',
#     'release_date': '1967-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0zR6CIh3f8DFFzIee5AWwp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1bs7HoMkSyQwcobCpE9KpN'},
#      'href': 'https://api.spotify.com/v1/artists/1bs7HoMkSyQwcobCpE9KpN',
#      'id': '1bs7HoMkSyQwcobCpE9KpN',
#      'name': 'The Mamas & The Papas',
#      'type': 'artist',
#      'uri': 'spotify:artist:1bs7HoMkSyQwcobCpE9KpN'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 178733,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC16746383'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1mFrjW8e8fuAOowlU3Q3Dr'},
#    'href': 'https://api.spotify.com/v1/tracks/1mFrjW8e8fuAOowlU3Q3Dr',
#    'id': '1mFrjW8e8fuAOowlU3Q3Dr',
#    'is_local': False,
#    'name': 'Dedicated To The One I Love',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/04716eddf51c275e05b7dd4c7eac8961e323f7e6?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1mFrjW8e8fuAOowlU3Q3Dr'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WHFu22zN1C6F11Z1rt12K'},
#       'href': 'https://api.spotify.com/v1/artists/1WHFu22zN1C6F11Z1rt12K',
#       'id': '1WHFu22zN1C6F11Z1rt12K',
#       'name': 'Jerro',
#       'type': 'artist',
#       'uri': 'spotify:artist:1WHFu22zN1C6F11Z1rt12K'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ikID9RZZMvkuBGDWrqajq'},
#       'href': 'https://api.spotify.com/v1/artists/1ikID9RZZMvkuBGDWrqajq',
#       'id': '1ikID9RZZMvkuBGDWrqajq',
#       'name': 'Kasbo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ikID9RZZMvkuBGDWrqajq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/784uIN74gtMGGKTQNDnB4U'},
#     'href': 'https://api.spotify.com/v1/albums/784uIN74gtMGGKTQNDnB4U',
#     'id': '784uIN74gtMGGKTQNDnB4U',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273497dac32cd31593b99261ec6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02497dac32cd31593b99261ec6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851497dac32cd31593b99261ec6',
#       'width': 64}],
#     'name': 'How Does It Feel',
#     'release_date': '2024-04-18',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:784uIN74gtMGGKTQNDnB4U'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WHFu22zN1C6F11Z1rt12K'},
#      'href': 'https://api.spotify.com/v1/artists/1WHFu22zN1C6F11Z1rt12K',
#      'id': '1WHFu22zN1C6F11Z1rt12K',
#      'name': 'Jerro',
#      'type': 'artist',
#      'uri': 'spotify:artist:1WHFu22zN1C6F11Z1rt12K'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ikID9RZZMvkuBGDWrqajq'},
#      'href': 'https://api.spotify.com/v1/artists/1ikID9RZZMvkuBGDWrqajq',
#      'id': '1ikID9RZZMvkuBGDWrqajq',
#      'name': 'Kasbo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ikID9RZZMvkuBGDWrqajq'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 297803,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBEWA2400030'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1hrle9bhEQsnykiEWXzDa9'},
#    'href': 'https://api.spotify.com/v1/tracks/1hrle9bhEQsnykiEWXzDa9',
#    'id': '1hrle9bhEQsnykiEWXzDa9',
#    'is_local': False,
#    'name': 'How Does It Feel',
#    'popularity': 43,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9868541849042c25daf4d514780a9c972528e7b6?cid=08c54b4fe8824e5693b53ee906156053',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1hrle9bhEQsnykiEWXzDa9'}],
#  'total': 1108,
#  'limit': 20,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?offset=0&limit=20&time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?offset=20&limit=20&time_range=short_term',
#  'previous': None}

# %%
def get_track_ids(time_frame):
    track_ids = []
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids = get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['3s5Rz3KFms39ZrFDw2jt4r',
#  '7oZkLL5Xct7ygMlCKArnCC',
#  '3eNVm12Ns8BOk4NqgWcGI4',
#  '6ncNLU982iaD9WFb2gTwKd',
#  '2wbirG6r5fn6UCzmKA8bpX',
#  '72l7APwXnXpffgZBCewEqX',
#  '0ibpvxLcFccvQJd0SjdUvW',
#  '1g7cixLX5jYl0uaTvYLM9V',
#  '4VlJbvK8wQFuIvAdMNw1Qu',
#  '7LZgdL0MxiElfaKZbuuE4l',
#  '0VNzEY1G4GLqcNx5qaaTl6',
#  '1TYMDPPJlOBtqREWR8jEwL',
#  '1WL9fq1sjsbyEEuHxBOvS9',
#  '1YM3cVri0CmSX7c71gwALR',
#  '2z4epffvWpEsAQvaCnkKBa',
#  '3hCUkos0NxuSFl73oOHJzb',
#  '5GJhomswiXnrn2Q1yJPsQG',
#  '270jwLvqL7UJOdeUyxwafh',
#  '1mFrjW8e8fuAOowlU3Q3Dr',
#  '1hrle9bhEQsnykiEWXzDa9']

# %%
track_id = '5ZicFGBDAi9J2YCVesboUp'

# %%
def get_track_features(id):
    meta = sp.track(id)
    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info = [name, album, artist, spotify_url, album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Professional',
#  'Kiss Land',
#  'The Weeknd',
#  'https://open.spotify.com/track/5ZicFGBDAi9J2YCVesboUp',
#  'https://i.scdn.co/image/ab67616d0000b273e4860d5331509e2c9ee4de10']

# %%
# loop over track ids 
tracks = []
for i in range(len(track_ids)):
    time.sleep(.5)
    track = get_track_features(track_ids[i])
    tracks.append(track)

# %%
tracks
# Out:
# [['Mehmaan',
#   'Mismatched: Season 2 (Soundtrack from the Netflix Series)',
#   'Mismatched - Cast',
#   'https://open.spotify.com/track/3s5Rz3KFms39ZrFDw2jt4r',
#   'https://i.scdn.co/image/ab67616d0000b27390853ed444266d1d2bb55c28'],
#  ['Main Title',
#   'Tale Of Cinema',
#   'Yongjin Jeong',
#   'https://open.spotify.com/track/7oZkLL5Xct7ygMlCKArnCC',
#   'https://i.scdn.co/image/ab67616d0000b27378129bba6aa1ae5f6f1c399b'],
#  ['Candy',
#   'Jaago',
#   'Lifafa',
#   'https://open.spotify.com/track/3eNVm12Ns8BOk4NqgWcGI4',
#   'https://i.scdn.co/image/ab67616d0000b273ccb8f637c8dd7422f4266bfa'],
#  ['Darling',
#   'Bloomsday',
#   'Esbe',
#   'https://open.spotify.com/track/6ncNLU982iaD9WFb2gTwKd',
#   'https://i.scdn.co/image/ab67616d0000b273c828c300386f6c77b7419119'],
#  ['Requiem Mass',
#   'Funeral',
#   'Laurent Levesque',
#   'https://open.spotify.com/track/2wbirG6r5fn6UCzmKA8bpX',
#   'https://i.scdn.co/image/ab67616d0000b273eb7886044bb004d4b79d1442'],
#  ['Obelisks',
#   'Sound to See ~ Visual Music, Vol. 2',
#   'Jesse Gallagher',
#   'https://open.spotify.com/track/72l7APwXnXpffgZBCewEqX',
#   'https://i.scdn.co/image/ab67616d0000b2730a4e6ad2800c26b04c8472ef'],
#  ['Connaissais de Face',
#   'Mordechai',
#   'Khruangbin',
#   'https://open.spotify.com/track/0ibpvxLcFccvQJd0SjdUvW',
#   'https://i.scdn.co/image/ab67616d0000b273d0eca87ea7f362cf1b8fa19a'],
#  ['Catching the first moment',
#   'Catching Moments in Time',
#   'Haythem Mahbouli',
#   'https://open.spotify.com/track/1g7cixLX5jYl0uaTvYLM9V',
#   'https://i.scdn.co/image/ab67616d0000b273ce5c651f3f05a4a3d1e3f49e'],
#  ['Sea of Dreams',
#   'Chronovision',
#   'Oberhofer',
#   'https://open.spotify.com/track/4VlJbvK8wQFuIvAdMNw1Qu',
#   'https://i.scdn.co/image/ab67616d0000b273c59a1af68ee4a33396660fbe'],
#  ['Asleep - 2011 Remaster',
#   'Louder Than Bombs',
#   'The Smiths',
#   'https://open.spotify.com/track/7LZgdL0MxiElfaKZbuuE4l',
#   'https://i.scdn.co/image/ab67616d0000b273ed3953f8af1f764a146b7583'],
#  ['Vincent',
#   'American Pie',
#   'Don McLean',
#   'https://open.spotify.com/track/0VNzEY1G4GLqcNx5qaaTl6',
#   'https://i.scdn.co/image/ab67616d0000b2730085dd4362653ef4c54ebbeb'],
#  ['Holiday House',
#   'Become',
#   'Beach House',
#   'https://open.spotify.com/track/1TYMDPPJlOBtqREWR8jEwL',
#   'https://i.scdn.co/image/ab67616d0000b273534f51f2ec60960b39d733d0'],
#  ['Sajna Ve Sajna',
#   'Chameli',
#   'Sandesh Shandilya',
#   'https://open.spotify.com/track/1WL9fq1sjsbyEEuHxBOvS9',
#   'https://i.scdn.co/image/ab67616d0000b273db065746f99e0572f2c26d70'],
#  ['The Trip - 2023 Remaster',
#   'Strange Pleasures: 10th Anniversary Edition (2023 Remaster)',
#   'Still Corners',
#   'https://open.spotify.com/track/1YM3cVri0CmSX7c71gwALR',
#   'https://i.scdn.co/image/ab67616d0000b2734f32976dd19a3fd1d380aec6'],
#  ['Zindagi Meri Dance Dance',
#   'Daddy',
#   'Sajid-Wajid',
#   'https://open.spotify.com/track/2z4epffvWpEsAQvaCnkKBa',
#   'https://i.scdn.co/image/ab67616d0000b273be0541e828776ae0df93d0bb'],
#  ["It's the Time to Disco",
#   'Kal Ho Naa Ho (Original Motion Picture Soundtrack)',
#   'Shankar-Ehsaan-Loy',
#   'https://open.spotify.com/track/3hCUkos0NxuSFl73oOHJzb',
#   'https://i.scdn.co/image/ab67616d0000b273a2055e0b847ff66fb5206099'],
#  ['Acche Din',
#   'SUPERPOWER 2020',
#   'Lifafa',
#   'https://open.spotify.com/track/5GJhomswiXnrn2Q1yJPsQG',
#   'https://i.scdn.co/image/ab67616d0000b273631595248a8dcbd3fda86368'],
#  ['Home - Extended Mix',
#   'Home',
#   'Eelke Kleijn',
#   'https://open.spotify.com/track/270jwLvqL7UJOdeUyxwafh',
#   'https://i.scdn.co/image/ab67616d0000b2738c00742a7071524def6fbf65'],
#  ['Dedicated To The One I Love',
#   'Deliver',
#   'The Mamas & The Papas',
#   'https://open.spotify.com/track/1mFrjW8e8fuAOowlU3Q3Dr',
#   'https://i.scdn.co/image/ab67616d0000b27391d092488eaff72ece2451dd'],
#  ['How Does It Feel',
#   'How Does It Feel',
#   'Jerro',
#   'https://open.spotify.com/track/1hrle9bhEQsnykiEWXzDa9',
#   'https://i.scdn.co/image/ab67616d0000b273497dac32cd31593b99261ec6']]

# %%
# create dataset
df_short = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
df_short.head(5)
# Out:
#            name                                              album  \
# 0       Mehmaan  Mismatched: Season 2 (Soundtrack from the Netf...
# 1    Main Title                                     Tale Of Cinema
# 2         Candy                                              Jaago
# 3       Darling                                          Bloomsday
# 4  Requiem Mass                                            Funeral
#
#               artist                                        spotify_url  \
# 0  Mismatched - Cast  https://open.spotify.com/track/3s5Rz3KFms39ZrF...
# 1      Yongjin Jeong  https://open.spotify.com/track/7oZkLL5Xct7ygMl...
# 2             Lifafa  https://open.spotify.com/track/3eNVm12Ns8BOk4N...
# 3               Esbe  https://open.spotify.com/track/6ncNLU982iaD9WF...
# 4   Laurent Levesque  https://open.spotify.com/track/2wbirG6r5fn6UCz...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b27390853e...
# 1  https://i.scdn.co/image/ab67616d0000b27378129b...
# 2  https://i.scdn.co/image/ab67616d0000b273ccb8f6...
# 3  https://i.scdn.co/image/ab67616d0000b273c828c3...
# 4  https://i.scdn.co/image/ab67616d0000b273eb7886...

# %%
top_tracks_med = sp.current_user_top_tracks(limit=20, offset=0, time_range="medium_term")
top_tracks_long = sp.current_user_top_tracks(limit=20, offset=0, time_range="long_term")

# %%
gc = gspread.service_account(filename='my-spotify-wrapped-359115-b93d1d9a2ed6.json')

# %%
sh = gc.open("My Spotify Wrapped")

# %%
worksheet = sh.worksheet("short_term")

# %%
val = worksheet.acell('A1').value
val
# Out:
# 'name'

# %%
# worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# %%
# insert into sheet
def insert_to_gsheet(track_ids):
    # loop over track ids 
    tracks = []
    for i in range(len(track_ids)):
        time.sleep(.5)
        track = get_track_features(track_ids[i])
        tracks.append(track)
    # create dataframe
    df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
    # insert into google sheet
    gc = gspread.service_account(filename='my-spotify-wrapped-359115-b93d1d9a2ed6.json')
    sh = gc.open('My Spotify Wrapped')
    worksheet = sh.worksheet(f'{time_period}')
    worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print('Done')

# %%
time_ranges = ['short_term', 'medium_term', 'long_term']
for time_period in time_ranges:
    top_tracks = sp.current_user_top_tracks(limit=20, offset=0, time_range=time_period)
    track_ids = get_track_ids(top_tracks)
    insert_to_gsheet(track_ids)
# Out:
# Done
# Done
# Done

# %%
def convert_to_df(track_ids):
 # loop over track ids 
 tracks = []
 for i in range(len(track_ids)):
    time.sleep(.5)
    track = get_track_features(track_ids[i])
    tracks.append(track)
 # create dataset
 df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
 # save to CSV
 df.to_csv(f'Aug-{time_period}.csv')

# %%
time_ranges = ['short_term', 'medium_term', 'long_term']
for time_period in time_ranges:
 top_tracks = sp.current_user_top_tracks(limit=20, offset=0, time_range=time_period)
 track_ids = get_track_ids(top_tracks)
 convert_to_df(track_ids)
